# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Constituent stocks data
stocks_data = {
    'Date': ['2024-02-25', '2024-02-25', '2024-02-25', '2024-02-25', '2024-02-25', '2024-02-25', '2024-02-25'],
    'Ticker': ['AAPL', 'MSFT', 'AMZN', 'GOOG', 'FB', 'TSLA', 'JPM'],
    'Portfolio Weight': ['14.29%', '14.29%', '14.29%', '14.29%', '14.29%', '14.29%', '14.29%'],
    'Annualized Volatility': ['25.6%', '22.1%', '28.3%', '21.8%', '27.5%', '45.2%', '18.7%'],
    'Beta (SPY)': [1.05, 0.98, 1.25, 1.15, 1.20, 1.50, 0.90],
    'Beta (IWM)': [0.95, 0.92, 1.05, 0.98, 1.10, 1.25, 0.85],
    'Beta (DIA)': [1.15, 1.12, 1.30, 1.20, 1.25, 1.40, 1.00],
    'Avg Weekly Drawdown': ['3.2%', '2.8%', '4.5%', '2.6%', '4.1%', '6.8%', '1.8%'],
    'Max Weekly Drawdown': ['5.7%', '4.5%', '7.2%', '4.1%', '6.3%', '11.2%', '3.0%'],
    'Total Return': ['250.5%', '210.2%', '280.9%', '220.4%', '260.7%', '310.6%', '180.3%'],
    'Annualized Total Return': ['12.3%', '10.8%', '13.6%', '11.0%', '12.9%', '14.8%', '9.5%']

}

# ETF data
etf_data = {
    'ETF Ticker': ['SPY', 'IWM', 'DIA'],
    'Correlation': [0.85, 0.72, 0.78],
    'Covariance': [0.0012, 0.0015, 0.0014],
    'Tracking Error': [0.021, 0.028, 0.025],
    'Sharpe Ratio': [1.25, 1.10, 1.15],
    'Volatility Spread': ['-2.7%', '1.3%', '-0.8%']
}

# Create DataFrame for stocks and ETFs
stocks_df = pd.DataFrame(stocks_data)
etf_df = pd.DataFrame(etf_data)

# Correlation matrix data
correlation_data = {
    'AAPL': [1.0, 0.85, 0.92, 0.78, 0.81, 0.65, 0.55, 0.72, 0.62, 0.68],
    'MSFT': [0.85, 1.0, 0.88, 0.75, 0.79, 0.60, 0.52, 0.68, 0.59, 0.64],
    'AMZN': [0.92, 0.88, 1.0, 0.82, 0.85, 0.68, 0.58, 0.75, 0.65, 0.72],
    'GOOG': [0.78, 0.75, 0.82, 1.0, 0.73, 0.59, 0.48, 0.65, 0.55, 0.60],
    'FB': [0.81, 0.79, 0.85, 0.73, 1.0, 0.63, 0.53, 0.70, 0.60, 0.66],
    'TSLA': [0.65, 0.60, 0.68, 0.59, 0.63, 1.0, 0.45, 0.58, 0.50, 0.55],
    'JPM': [0.55, 0.52, 0.58, 0.48, 0.53, 0.45, 1.0, 0.45, 0.40, 0.42],
    'SPY': [0.72, 0.68, 0.75, 0.65, 0.70, 0.58, 0.45, 1.0, 0.85, 0.92],
    'IWM': [0.62, 0.59, 0.65, 0.55, 0.60, 0.50, 0.40, 0.85, 1.0, 0.88],
    'DIA': [0.68, 0.64, 0.72, 0.60, 0.66, 0.55, 0.42, 0.92, 0.88, 1.0]
}


# Create DataFrame for stocks
stocks_df = pd.DataFrame(stocks_data)

# Create DataFrame for ETFs
etfs_df = pd.DataFrame(etfs_data)

# Create correlation matrix DataFrame
correlation_data = {
    "Ticker": stocks_data["Ticker"],
    **{etf: np.random.rand(len(stocks_data["Ticker"])) for etf in etfs_data["ETF Ticker"]},
    **{stock: np.random.rand(len(stocks_data["Ticker"])) for stock in stocks_data["Ticker"]}
}
correlation_df = pd.DataFrame(correlation_data)

# Calculate correlation matrix
correlation_matrix = correlation_df.corr()

# Plot correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# Print stocks DataFrame
print("Stocks DataFrame:")
print(stocks_df)

# Print ETFs DataFrame
print("\nETFs DataFrame:")
print(etfs_df)

# Print correlation matrix DataFrame
print("\nCorrelation Matrix DataFrame:")
print(correlation_matrix)
# Out:
# <ipython-input-30-5a519273aefa>:66: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = correlation_df.corr()
# Stocks DataFrame:
#          Date Ticker Portfolio Weight Annualized Volatility  Beta (SPY)  \
# 0  2024-02-25   AAPL           14.29%                 25.6%        1.05
# 1  2024-02-25   MSFT           14.29%                 22.1%        0.98
# 2  2024-02-25   AMZN           14.29%                 28.3%        1.25
# 3  2024-02-25   GOOG           14.29%                 21.8%        1.15
# 4  2024-02-25     FB           14.29%                 27.5%        1.20
# 5  2024-02-25   TSLA           14.29%                 45.2%        1.50
# 6  2024-02-25    JPM           14.29%                 18.7%        0.90
#
#    Beta (IWM)  Beta (DIA) Avg Weekly Drawdown Max Weekly Drawdown  \
# ...
